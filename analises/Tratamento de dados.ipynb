# %% [markdown]
# # Tratando dados para a análise

# %%
import pandas as pd

# %%
df_vendas = pd.read_excel('../DataSet/DataSet_Test.xlsx')

# %%
df_vendas.head(20)
# Out:
#     BillNo                             Itemname  Quantity                Date  \
# 0   536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1   536365                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2   536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3   536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4   536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# 5   536365         SET 7 BABUSHKA NESTING BOXES         2 2010-12-01 08:26:00
# 6   536365    GLASS STAR FROSTED T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 7   536366               HAND WARMER UNION JACK         6 2010-12-01 08:28:00
# 8   536366            HAND WARMER RED POLKA DOT         6 2010-12-01 08:28:00
# 9   536367        ASSORTED COLOUR BIRD ORNAMENT        32 2010-12-01 08:34:00
# 10  536367            POPPY'S PLAYHOUSE BEDROOM         6 2010-12-01 08:34:00
# ...

# %% [markdown]
# ## Tirando registro com a coluna country 'Unspecified'

# %%
#Estes registro são dados que não se incluem na analise pois não são vendas de fato
df_lixo = (df_vendas['Country'] == 'Unspecified')
df_vendas_novo = df_vendas[~df_lixo]
df_vendas_novo
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                       Date  Price  CustomerID         Country
# 0      2010-12-01 08:26:00   2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00   3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# ## Tirando valores nulos

# %%
df_vendas_novo.dropna(inplace=True, how='any')
df_vendas_novo
# Out:
# /tmp/ipykernel_2859/3537448415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vendas_novo.dropna(inplace=True, how='any')
#         BillNo                             Itemname  Quantity       Date  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-01-12
# 1       536365                  WHITE METAL LANTERN         6 2010-01-12
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8 2010-01-12
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-01-12
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-01-12
# ...        ...                                  ...       ...        ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12 2011-09-12
# ...

# %% [markdown]
# ## Tirando as horas da coluna Date

# %%
df_vendas_novo['Date'] = pd.to_datetime(df_vendas_novo['Date'].dt.strftime('%d/%m/%y')) 
df_vendas_novo
# Out:
# /tmp/ipykernel_2859/1195640263.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vendas_novo['Date'] = pd.to_datetime(df_vendas_novo['Date'].dt.strftime('%d/%m/%y'))
#         BillNo                             Itemname  Quantity       Date  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01
# 1       536365                  WHITE METAL LANTERN         6 2010-12-01
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01
# ...        ...                                  ...       ...        ...
# ...

# %% [markdown]
# ## Exportando novo DataSet

# %%
df_vendas_novo.to_excel('../DataSet/DataSetNovo.xlsx')
